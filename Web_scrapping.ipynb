# %% [markdown]
# <a href="https://colab.research.google.com/github/ritesh-chafer/Coronavirus_Enrichment/blob/master/Web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date
today = date.today()
d = today.strftime("%m-%d-%y")
print("date =", d)
# Out:
# date = 10-07-20

# %%
cnn_url = "https://edition.cnn.com/world/live-news/coronavirus-pandemic-{}-intl/index.html".format(d)

# %%
print(cnn_url)
# Out:
# https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html

# %%
from bs4 import BeautifulSoup
import requests

# %%
html = requests.get(cnn_url).text

# %%
soup = BeautifulSoup(html)
print(soup.title)
# Out:
# <title data-rh="true">Coronavirus update: Latest world news for October 7</title>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
for link in soup.find_all("h2"):
  print("headline : {}".format(link.text))
  for ent in nlp(link.text).ents:
    print("\text : {}, Entity :{}".format(ent.text,ent.label_))
# Out:
# headline : What you need to know
# headline : Brazil surpasses 5 million Covid-19 cases
# 	ext : Brazil, Entity :GPE
# 	ext : 5 million, Entity :CARDINAL
# headline : Prestigious medical journal calls for US leadership to be voted out of office
# 	ext : US, Entity :GPE
# headline : Jury trials will be allowed to resume in Georgia
# 	ext : Georgia, Entity :GPE
# headline : Wisconsin reports record number of new Covid-19 hospitalizations
# 	ext : Wisconsin, Entity :GPE
# headline : Staff member in California governor's office tests positive for Covid-19
# 	ext : California, Entity :GPE
# headline : Canada’s weekly average of new Covid-19 cases reaches an all-time high
# 	ext : Canada, Entity :GPE
# 	ext : weekly, Entity :DATE
# headline : Nevada governor tests negative for Covid-19 after a staffer tests positive
# 	ext : Nevada, Entity :GPE
# headline : NFL doctor won't rule out pausing season after 26 Covid-19 cases reported within past week
# 	ext : NFL, Entity :ORG
# 	ext : 26, Entity :CARDINAL
# 	ext : past week, Entity :DATE
# headline : The United Nations High Commissioner for Refugees tested positive for Covid-19
# 	ext : The United Nations High Commissioner, Entity :ORG

# %%
nbc_url = 'https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url = 'https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
urls = [cnn_url, nbc_url, cnbc_rss_url]
formats = ['html.parser','html.parser','xml']
tags = ['h2', 'h2', 'description']
website = ['CNN', 'NBC','CNBC']

# %%
crawl_len=0
for url in urls:
  print("crawling web page ..........{}".format(url))
  response = requests.get(url)
  soup = BeautifulSoup(response.content, formats[crawl_len])
  for link in soup.find_all(tags[crawl_len]):
    if(len(link.text.split(" ")) > 4):
      print("Headline : {}".format(link.text))
      entities = []
      for ent in nlp(link.text).ents:
        print("\tText: {}, Entity:{}".format(ent.text, ent.label_))
  crawl_len = crawl_len+1
# Out:
# crawling web page ..........https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html
# Headline : What you need to know
# Headline : Brazil surpasses 5 million Covid-19 cases
# 	Text: Brazil, Entity:GPE
# 	Text: 5 million, Entity:CARDINAL
# Headline : Prestigious medical journal calls for US leadership to be voted out of office
# 	Text: US, Entity:GPE
# Headline : Jury trials will be allowed to resume in Georgia
# 	Text: Georgia, Entity:GPE
# Headline : Wisconsin reports record number of new Covid-19 hospitalizations
# 	Text: Wisconsin, Entity:GPE
# Headline : Staff member in California governor's office tests positive for Covid-19
# 	Text: California, Entity:GPE
# Headline : Canada’s weekly average of new Covid-19 cases reaches an all-time high
# 	Text: Canada, Entity:GPE
# 	Text: weekly, Entity:DATE
# Headline : Nevada governor tests negative for Covid-19 after a staffer tests positive
# 	Text: Nevada, Entity:GPE
# Headline : NFL doctor won't rule out pausing season after 26 Covid-19 cases reported within past week
# 	Text: NFL, Entity:ORG
# 	Text: 26, Entity:CARDINAL
# 	Text: past week, Entity:DATE
# Headline : The United Nations High Commissioner for Refugees tested positive for Covid-19
# 	Text: The United Nations High Commissioner, Entity:ORG
# crawling web page ..........https://www.nbcnews.com/health/coronavirus
# Headline : Trump returns to White House infected with COVID-19
# 	Text: White House, Entity:ORG
# Headline : Pence pulls plug on plexiglass protest
# 	Text: Pence, Entity:ORG
# Headline : Stephen Miller, top White House adviser, is self-isolating after testing positive for coronavirus
# 	Text: Stephen Miller, Entity:PERSON
# 	Text: White House, Entity:ORG
# Headline : Pence, Harris spar over plexiglass barriers at VP debate
# 	Text: Pence, Harris, Entity:ORG
# 	Text: VP, Entity:ORG
# Headline : Another of McEnany's aides tests positive
# 	Text: McEnany, Entity:ORG
# Headline : 'Morally reprehensible': Doctors react to Trump's tweet comparing Covid-19 to flu
# 	Text: Trump, Entity:PERSON
# Headline : D.C.-area House Democrats call White House coronavirus outbreak "out of control"
# 	Text: House, Entity:ORG
# 	Text: Democrats, Entity:NORP
# 	Text: White House, Entity:ORG
# Headline : Gen. Milley, other members of Joint Chiefs quarantine after admiral tests positive for Covid-19
# 	Text: Milley, Entity:PERSON
# 	Text: Joint Chiefs, Entity:ORG
# Headline : Joint Chiefs of Staff go into quarantine after potential covid exposure
# 	Text: Joint Chiefs of Staff, Entity:ORG
# Headline : Commission discussing holding presidential debates outside
# Headline : Trump's 'reckless' New Jersey fundraiser is under state review
# 	Text: Trump, Entity:PERSON
# 	Text: New Jersey, Entity:GPE
# Headline : Older voters flee Trump, solidifying Biden's advantage in the 2020 race
# 	Text: Trump, Entity:PRODUCT
# 	Text: Biden, Entity:PERSON
# 	Text: 2020, Entity:DATE
# Headline : Michelle Obama thanks White House residence staff, Secret Service after Trump returns home
# 	Text: Michelle Obama, Entity:PERSON
# 	Text: White House, Entity:ORG
# 	Text: Secret Service, Entity:ORG
# 	Text: Trump, Entity:PRODUCT
# crawling web page ..........https://www.cnbc.com/id/10000108/device/rss/rss.html
# Headline : Latest news for health care.
# Headline : "When I saw it I laughed, but it's not funny," Kimberly Prather, a distinguished professor of atmospheric chemistry at the University of California at San Diego, said of the barriers.
# 	Text: Kimberly Prather, Entity:PERSON
# 	Text: the University of California at San Diego, Entity:ORG
# Headline : Some 17,000 Delta employees have already accepted buyouts and early retirement offers. The airline said its goal isn't to reduce headcount.
#
# 	Text: Some 17,000, Entity:CARDINAL
# 	Text: Delta, Entity:LOC
# Headline : Shares of Eli Lilly rose on Wednesday after the company announced it submitted a request to the U.S. FDA for emergency authorization of its Covid-19 antibody treatment.
# 	Text: Eli Lilly, Entity:ORG
# 	Text: Wednesday, Entity:DATE
# 	Text: the U.S. FDA, Entity:ORG
# Headline : Multiple people linked to President Trump have tested positive for coronavirus, including Trump himself, Melania Trump, Hope Hicks and Kayleigh McEnany.
# 	Text: Trump, Entity:PERSON
# 	Text: Trump, Entity:LOC
# 	Text: Melania Trump, Entity:PERSON
# 	Text: Hope Hicks, Entity:PERSON
# Headline : "Many deaths have been averted and many more lives can be protected," Dr. Mike Ryan, executive director of the WHO's health emergencies program, said Monday.
# 	Text: Mike Ryan, Entity:PERSON
# 	Text: WHO, Entity:ORG
# 	Text: Monday, Entity:DATE
# Headline : GlaxoSmithKline (GSK) has told around 2,500 staff in Britain to turn off a Covid-19 contact-tracing app while at work.
# 	Text: GSK, Entity:ORG
# 	Text: around 2,500, Entity:CARDINAL
# 	Text: Britain, Entity:GPE
# Headline : Dow futures advanced Wednesday after President Trump's late night tweet prodding Capitol Hill to approve additional coronavirus relief in separate bills.
# 	Text: Wednesday, Entity:DATE
# 	Text: Trump, Entity:PERSON
# 	Text: late night, Entity:TIME
# 	Text: Capitol Hill, Entity:ORG
# Headline : From migraines to fatigue, coronavirus patients say they are continuing to suffer debilitating symptoms months after first becoming infected, in what has become known as "long Covid."
# 	Text: months, Entity:DATE
# 	Text: first, Entity:ORDINAL
# Headline : "Why would you concede to this and lose?" one Wall Street banker asked. "It's not like Donald Trump gives a s--- about the deficit."
# 	Text: one, Entity:CARDINAL
# 	Text: Donald Trump, Entity:PERSON
# 	Text: s---, Entity:PRODUCT
# Headline : Rick Bright, the Trump administration vaccine expert turned whistleblower, resigned from the federal government Tuesday, according to a press release from his lawyer.
# 	Text: Rick Bright, Entity:PERSON
# 	Text: Trump, Entity:PERSON
# 	Text: Tuesday, Entity:DATE
# Headline : Dr. Deborah Birx, the White House coronavirus task force coordinator, emphasized that the data is "really critical" to guide the U.S. response to the pandemic.
# 	Text: Deborah Birx, Entity:PERSON
# 	Text: White House, Entity:ORG
# 	Text: U.S., Entity:GPE
# Headline : "I do think this time we'll learn and we'll have innovations so the next time this happens, we'll do better, but we're still dealing with the mistakes of February and March," Bill Gates said of the U.S. coronavirus response.
# 	Text: February, Entity:DATE
# 	Text: March, Entity:DATE
# 	Text: Bill Gates, Entity:PERSON
# 	Text: U.S., Entity:GPE
# Headline : Johns Hopkins University and the University of Washington are holding a series of panels on Tuesday with the nation's top health officials as part of a Covid-19 vaccine symposium.
# 	Text: Johns Hopkins University, Entity:ORG
# 	Text: the University of Washington, Entity:ORG
# 	Text: Tuesday, Entity:DATE
# Headline : The subcommittee is seeking documents and information from the FDA and CDC on agency actions, drafts submitted to the White House and changes made during the review process.
# 	Text: FDA, Entity:ORG
# 	Text: CDC, Entity:ORG
# 	Text: the White House, Entity:ORG
# Headline : The president's tweet came less than 24 hours after he was discharged from the hospital for Covid-19 treatment.
# 	Text: less than 24 hours, Entity:TIME
# Headline : Boeing slashed its 10-year forecast for new aircraft demand by 11% from a year ago, citing the impact of Covid-19.
# 	Text: Boeing, Entity:ORG
# 	Text: 11%, Entity:PERCENT
# 	Text: a year ago, Entity:DATE
# Headline : "The idea that, until that course of care is broadly available, that we can behave and act as the president, is just not realistic," entrepreneur Chamath Palihapitiya said
# 	Text: Palihapitiya, Entity:PERSON
# Headline : "It's not so much about getting this bill passed in terms of, 'we want another loan.' We just want to go back to work," restaurateur Marcus Samuelsson told CNBC on Tuesday.
# 	Text: Marcus Samuelsson, Entity:PERSON
# 	Text: CNBC, Entity:ORG
# 	Text: Tuesday, Entity:DATE
# Headline : Rising levels of "Covid-19 fatigue" are being seen in Europe, the regional director of the World Health Organisation warned.
# 	Text: Europe, Entity:LOC
# 	Text: the World Health Organisation, Entity:ORG
# Headline : The Central of Bank of Ireland published its quarterly bulletin Tuesday morning where it substantially adjusted its full-year forecast for GDP.
# 	Text: The Central of Bank of Ireland, Entity:ORG
# 	Text: quarterly, Entity:DATE
# 	Text: Tuesday, Entity:DATE
# 	Text: morning, Entity:TIME
# 	Text: full-year, Entity:DATE
# Headline : Dow futures pointed to a higher Tuesday open after Wall Street soared following President Trump's tweet that he was leaving Walter Reed on Monday evening.
# 	Text: Tuesday, Entity:DATE
# 	Text: Trump, Entity:PERSON
# 	Text: Walter Reed, Entity:PERSON
# 	Text: Monday, Entity:DATE
# 	Text: evening, Entity:TIME
# Headline : President Trump wants to appear strong despite testing positive for the coronavirus, said David Smith of the United States Studies Centre at the University of Sydney.
# 	Text: Trump, Entity:PERSON
# 	Text: David Smith, Entity:PERSON
# 	Text: the United States Studies Centre, Entity:ORG
# 	Text: the University of Sydney, Entity:ORG
# Headline : President Trump's return to the White House despite being still infected isn't helpful in combatting the virus because it shows he still doesn't take it seriously, analysts say.
# 	Text: Trump, Entity:PERSON
# 	Text: the White House, Entity:ORG
# Headline : Last July, regulations around short-term rentals came into effect with a "one host, one home" model that is enforced by local planning authorities.
# 	Text: Last July, Entity:DATE
# 	Text: one, Entity:CARDINAL
# 	Text: one, Entity:CARDINAL
# Headline : President Donald Trump has the coronavirus. And a number of people in his orbit have been diagnosed with Covid-19 since his debate with Joe Biden.
# 	Text: Donald Trump, Entity:PERSON
# 	Text: Joe Biden, Entity:PERSON
# Headline : "CDC's recommendations remain the same based on existing science and after a thorough technical review of the guidance," the agency said.
# 	Text: CDC, Entity:ORG
# Headline : "We don't really have any evidence for the melange of this particular brew. It may be perfect. It may not be right. We just don't know," Dr. Lewis Kaplan, a surgeon at the hospital of the University of Pennsylvania.
# 	Text: Lewis Kaplan, Entity:PERSON
# 	Text: the University of Pennsylvania, Entity:ORG
# Headline : Kayleigh McEnany is one of at least18 people linked to the White House, including President Trump, Melania Trump and Hope Hicks, who have tested positive for Covid-19.
# 	Text: Kayleigh McEnany, Entity:ORG
# 	Text: one, Entity:CARDINAL
# 	Text: the White House, Entity:ORG
# 	Text: Trump, Entity:PERSON
# 	Text: Trump, Entity:PERSON
# 	Text: Hope Hicks, Entity:PERSON
# Headline : Dr. Carolyn McClanahan shares questions to help you understand how common health issues and health-care policy can affect finances.
# 	Text: Carolyn McClanahan, Entity:PERSON
# Headline : "We have tried to take a principled approach until there is a broader authorization," CEO Dr. Leonard Schleifer told CNBC.
# 	Text: Leonard Schleifer, Entity:PERSON
# 	Text: CNBC, Entity:ORG

# %%
crawl_len = 0
news_dict = []
for url in urls:
  response = requests.get(url)
  soup = BeautifulSoup(response.content, formats[crawl_len])
  for link in soup.find_all(tags[crawl_len]):
    if(len(link.text.split(" ")) > 4):
      entities = []
      entities = [(ent.text, ent.label_) for ent in nlp(link.text).ents]
      news_dict.append({'website':website[crawl_len],'url':url,'headline':link.text,'entities':entities})
  crawl_len = crawl_len + 1

# %%
news_dict
# Out:
# [{'entities': [],
#   'headline': 'What you need to know',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('Brazil', 'GPE'), ('5 million', 'CARDINAL')],
#   'headline': 'Brazil surpasses 5 million Covid-19 cases\xa0',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('US', 'GPE')],
#   'headline': 'Prestigious medical journal calls for US leadership to be voted out of office',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('Georgia', 'GPE')],
#   'headline': 'Jury trials will be allowed to resume in Georgia',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('Wisconsin', 'GPE')],
#   'headline': 'Wisconsin reports record number of new Covid-19 hospitalizations',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('California', 'GPE')],
#   'headline': "Staff member in California governor's office tests positive for Covid-19",
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('Canada', 'GPE'), ('weekly', 'DATE')],
#   'headline': 'Canada’s weekly average of new Covid-19 cases reaches an all-time high',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('Nevada', 'GPE')],
#   'headline': 'Nevada governor tests negative for Covid-19 after a staffer tests positive',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('NFL', 'ORG'), ('26', 'CARDINAL'), ('past week', 'DATE')],
#   'headline': "NFL doctor won't rule out pausing season after 26 Covid-19 cases reported within past week",
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('The United Nations High Commissioner', 'ORG')],
#   'headline': 'The United Nations High Commissioner for Refugees tested positive for Covid-19',
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-10-07-20-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [('White House', 'ORG')],
#   'headline': 'Trump returns to White House infected with COVID-19',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Pence', 'ORG')],
#   'headline': 'Pence pulls plug on plexiglass protest',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Stephen Miller', 'PERSON'), ('White House', 'ORG')],
#   'headline': 'Stephen Miller, top White House adviser, is self-isolating after testing positive for coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Pence, Harris', 'ORG'), ('VP', 'ORG')],
#   'headline': 'Pence, Harris spar over plexiglass barriers at VP debate',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('McEnany', 'ORG')],
#   'headline': "Another of McEnany's aides tests positive",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'PERSON')],
#   'headline': "'Morally reprehensible': Doctors react to Trump's tweet comparing Covid-19 to flu",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('House', 'ORG'),
#    ('Democrats', 'NORP'),
#    ('White House', 'ORG')],
#   'headline': 'D.C.-area House Democrats call White House coronavirus outbreak "out of control"',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Milley', 'PERSON'), ('Joint Chiefs', 'ORG')],
#   'headline': 'Gen. Milley, other members of Joint Chiefs quarantine after admiral tests positive for Covid-19',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Joint Chiefs of Staff', 'ORG')],
#   'headline': 'Joint Chiefs of Staff go into quarantine after potential covid exposure',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Commission discussing holding presidential debates outside',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'PERSON'), ('New Jersey', 'GPE')],
#   'headline': "Trump's 'reckless' New Jersey fundraiser is under state review",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'PRODUCT'), ('Biden', 'PERSON'), ('2020', 'DATE')],
#   'headline': "Older voters flee Trump, solidifying Biden's advantage in the 2020 race",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Michelle Obama', 'PERSON'),
#    ('White House', 'ORG'),
#    ('Secret Service', 'ORG'),
#    ('Trump', 'PRODUCT')],
#   'headline': 'Michelle Obama thanks White House residence staff, Secret Service after Trump returns home',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Latest news for health care. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Kimberly Prather', 'PERSON'),
#    ('the University of California at San Diego', 'ORG')],
#   'headline': '"When I saw it I laughed, but it\'s not funny," Kimberly Prather, a distinguished professor of atmospheric chemistry at the University of California at San Diego, said of the barriers.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Some 17,000', 'CARDINAL'), ('Delta', 'LOC')],
#   'headline': "Some 17,000 Delta employees have already accepted buyouts and early retirement offers. The airline said its goal isn't to reduce headcount.\n",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Eli Lilly', 'ORG'),
#    ('Wednesday', 'DATE'),
#    ('the U.S. FDA', 'ORG')],
#   'headline': 'Shares of Eli Lilly rose on Wednesday after the company announced it submitted a request to the U.S. FDA for emergency authorization of its Covid-19 antibody treatment.\xa0',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Trump', 'PERSON'),
#    ('Trump', 'LOC'),
#    ('Melania Trump', 'PERSON'),
#    ('Hope Hicks', 'PERSON')],
#   'headline': 'Multiple people linked to President Trump have tested positive for coronavirus, including Trump himself, Melania Trump, Hope Hicks and Kayleigh McEnany.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Mike Ryan', 'PERSON'), ('WHO', 'ORG'), ('Monday', 'DATE')],
#   'headline': '"Many deaths have been averted and many more lives can be protected," Dr. Mike Ryan, executive director of the WHO\'s health emergencies program, said Monday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('GSK', 'ORG'),
#    ('around 2,500', 'CARDINAL'),
#    ('Britain', 'GPE')],
#   'headline': 'GlaxoSmithKline (GSK) has told around 2,500 staff in Britain to turn off a Covid-19 contact-tracing app while at work.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Wednesday', 'DATE'),
#    ('Trump', 'PERSON'),
#    ('late night', 'TIME'),
#    ('Capitol Hill', 'ORG')],
#   'headline': "Dow futures advanced Wednesday after President Trump's late night tweet prodding Capitol Hill to approve additional coronavirus relief in separate bills.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('months', 'DATE'), ('first', 'ORDINAL')],
#   'headline': 'From migraines to fatigue, coronavirus patients say they are continuing to suffer debilitating symptoms months after first becoming infected, in what has become known as "long Covid."\xa0',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('one', 'CARDINAL'),
#    ('Donald Trump', 'PERSON'),
#    ('s---', 'PRODUCT')],
#   'headline': '"Why would you concede to this and lose?" one Wall Street banker asked. "It\'s not like Donald Trump gives a s--- about the deficit."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Rick Bright', 'PERSON'),
#    ('Trump', 'PERSON'),
#    ('Tuesday', 'DATE')],
#   'headline': 'Rick Bright, the Trump administration vaccine expert turned whistleblower, resigned from the federal government Tuesday, according to a press release from his lawyer.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Deborah Birx', 'PERSON'),
#    ('White House', 'ORG'),
#    ('U.S.', 'GPE')],
#   'headline': 'Dr. Deborah Birx,\xa0the White House coronavirus task force coordinator, emphasized that the data is "really critical" to guide the U.S. response to the pandemic.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('February', 'DATE'),
#    ('March', 'DATE'),
#    ('Bill Gates', 'PERSON'),
#    ('U.S.', 'GPE')],
#   'headline': '"I do think this time we\'ll learn and we\'ll have innovations so the next time this happens, we\'ll do better, but we\'re still dealing with the mistakes of February and March," Bill Gates said of the U.S. coronavirus response.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Johns Hopkins University', 'ORG'),
#    ('the University of Washington', 'ORG'),
#    ('Tuesday', 'DATE')],
#   'headline': "Johns Hopkins University and the University of Washington are holding a series of panels on Tuesday with the nation's top health officials as part of a Covid-19 vaccine symposium.\xa0",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('FDA', 'ORG'), ('CDC', 'ORG'), ('the White House', 'ORG')],
#   'headline': 'The subcommittee is seeking documents and information from the FDA and CDC on agency actions, drafts submitted to the White House and changes made during the review process.\xa0',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('less than 24 hours', 'TIME')],
#   'headline': "The president's tweet came less than 24 hours after he was discharged from the hospital for Covid-19 treatment.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Boeing', 'ORG'), ('11%', 'PERCENT'), ('a year ago', 'DATE')],
#   'headline': 'Boeing slashed its 10-year forecast for new aircraft demand by 11% from a year ago, citing the impact of Covid-19.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Palihapitiya', 'PERSON')],
#   'headline': '"The idea that, until that course of care is broadly available, that we can behave and act as the president, is just not realistic," entrepreneur Chamath Palihapitiya\xa0said ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Marcus Samuelsson', 'PERSON'),
#    ('CNBC', 'ORG'),
#    ('Tuesday', 'DATE')],
#   'headline': '"It\'s not so much about getting this bill passed in terms of, \'we want another loan.\' We just want to go back to work," restaurateur Marcus Samuelsson told CNBC on Tuesday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Europe', 'LOC'), ('the World Health Organisation', 'ORG')],
#   'headline': 'Rising levels of "Covid-19 fatigue" are being seen in Europe, the regional director of the World Health Organisation warned.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The Central of Bank of Ireland', 'ORG'),
#    ('quarterly', 'DATE'),
#    ('Tuesday', 'DATE'),
#    ('morning', 'TIME'),
#    ('full-year', 'DATE')],
#   'headline': 'The Central of Bank of Ireland published its quarterly bulletin Tuesday morning where it substantially adjusted its full-year forecast for GDP.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Tuesday', 'DATE'),
#    ('Trump', 'PERSON'),
#    ('Walter Reed', 'PERSON'),
#    ('Monday', 'DATE'),
#    ('evening', 'TIME')],
#   'headline': "Dow futures pointed to\xa0a higher Tuesday open after Wall Street soared following President Trump's tweet that he was leaving Walter Reed on Monday evening.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Trump', 'PERSON'),
#    ('David Smith', 'PERSON'),
#    ('the\xa0United States Studies Centre', 'ORG'),
#    ('the University of Sydney', 'ORG')],
#   'headline': 'President Trump wants to appear strong despite testing positive for the coronavirus, said\xa0David Smith of the\xa0United States Studies Centre at the University of Sydney.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Trump', 'PERSON'), ('the White House', 'ORG')],
#   'headline': "President Trump's return to the White House despite being still infected\xa0isn't helpful in combatting the virus because it shows he still doesn't take it seriously, analysts say.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Last July', 'DATE'),
#    ('one', 'CARDINAL'),
#    ('one', 'CARDINAL')],
#   'headline': 'Last July, regulations around short-term rentals came into effect with a "one host, one home" model that is enforced by local planning authorities.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Donald Trump', 'PERSON'), ('Joe Biden', 'PERSON')],
#   'headline': 'President Donald Trump has the coronavirus. And a number of people in his orbit have been diagnosed with Covid-19 since his debate with Joe Biden.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('CDC', 'ORG')],
#   'headline': '"CDC\'s recommendations remain the same based on existing science and after a thorough technical review of the guidance," the agency said. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Lewis Kaplan', 'PERSON'),
#    ('the University of Pennsylvania', 'ORG')],
#   'headline': '"We don\'t really have any evidence for the melange of this particular brew. It may be perfect. It may not be right. We just don\'t know," Dr. Lewis Kaplan, a surgeon at the\xa0hospital of the University of Pennsylvania.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Kayleigh McEnany', 'ORG'),
#    ('one', 'CARDINAL'),
#    ('the White House', 'ORG'),
#    ('Trump', 'PERSON'),
#    ('Trump', 'PERSON'),
#    ('Hope Hicks', 'PERSON')],
#   'headline': 'Kayleigh McEnany is one of at least18 people linked to the White House, including President Trump, Melania Trump and Hope Hicks, who have tested positive for Covid-19.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Carolyn McClanahan', 'PERSON')],
#   'headline': 'Dr. Carolyn McClanahan shares questions to help you understand how common health issues and health-care policy can affect finances.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Leonard Schleifer', 'PERSON'), ('CNBC', 'ORG')],
#   'headline': '"We have tried to take a principled approach until there is a broader\xa0authorization,"\xa0CEO Dr. Leonard Schleifer told CNBC.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'}]

# %%
import pandas as pd

# %%
news_df = pd.DataFrame(news_dict)

# %%
pd.set_option('max_colwidth', 800)
news_df.head(30)
# Out:
#    website  ...                                                                                 entities
# 0      CNN  ...                                                                                       []
# 1      CNN  ...                                                   [(Brazil, GPE), (5 million, CARDINAL)]
# 2      CNN  ...                                                                              [(US, GPE)]
# 3      CNN  ...                                                                         [(Georgia, GPE)]
# 4      CNN  ...                                                                       [(Wisconsin, GPE)]
# 5      CNN  ...                                                                      [(California, GPE)]
# 6      CNN  ...                                                          [(Canada, GPE), (weekly, DATE)]
# 7      CNN  ...                                                                          [(Nevada, GPE)]
# 8      CNN  ...                                          [(NFL, ORG), (26, CARDINAL), (past week, DATE)]
# 9      CNN  ...                                            [(The United Nations High Commissioner, ORG)]
# 10     NBC  ...                                                                     [(White House, ORG)]
# 11     NBC  ...                                                                           [(Pence, ORG)]
# 12     NBC  ...                                           [(Stephen Miller, PERSON), (White House, ORG)]
# 13     NBC  ...                                                        [(Pence, Harris, ORG), (VP, ORG)]
# 14     NBC  ...                                                                         [(McEnany, ORG)]
# 15     NBC  ...                                                                        [(Trump, PERSON)]
# 16     NBC  ...                                    [(House, ORG), (Democrats, NORP), (White House, ORG)]
# 17     NBC  ...                                                  [(Milley, PERSON), (Joint Chiefs, ORG)]
# 18     NBC  ...                                                           [(Joint Chiefs of Staff, ORG)]
# 19     NBC  ...                                                                                       []
# 20     NBC  ...                                                     [(Trump, PERSON), (New Jersey, GPE)]
# 21     NBC  ...                                        [(Trump, PRODUCT), (Biden, PERSON), (2020, DATE)]
# 22     NBC  ...  [(Michelle Obama, PERSON), (White House, ORG), (Secret Service, ORG), (Trump, PRODUCT)]
# 23    CNBC  ...                                                                                       []
# 24    CNBC  ...           [(Kimberly Prather, PERSON), (the University of California at San Diego, ORG)]
# 25    CNBC  ...                                                  [(Some 17,000, CARDINAL), (Delta, LOC)]
# 26    CNBC  ...                               [(Eli Lilly, ORG), (Wednesday, DATE), (the U.S. FDA, ORG)]
# 27    CNBC  ...           [(Trump, PERSON), (Trump, LOC), (Melania Trump, PERSON), (Hope Hicks, PERSON)]
# 28    CNBC  ...                                        [(Mike Ryan, PERSON), (WHO, ORG), (Monday, DATE)]
# 29    CNBC  ...                                   [(GSK, ORG), (around 2,500, CARDINAL), (Britain, GPE)]
#
# [30 rows x 4 columns]

# %%
pd.concat([news_df[['website','url','headline']],news_df['entities'].apply(pd.Series)],axis=1)
# Out:
#    website  ...                     5
# 0      CNN  ...                   NaN
# 1      CNN  ...                   NaN
# 2      CNN  ...                   NaN
# 3      CNN  ...                   NaN
# 4      CNN  ...                   NaN
# 5      CNN  ...                   NaN
# 6      CNN  ...                   NaN
# 7      CNN  ...                   NaN
# 8      CNN  ...                   NaN
# 9      CNN  ...                   NaN
# 10     NBC  ...                   NaN
# 11     NBC  ...                   NaN
# 12     NBC  ...                   NaN
# 13     NBC  ...                   NaN
# 14     NBC  ...                   NaN
# 15     NBC  ...                   NaN
# 16     NBC  ...                   NaN
# 17     NBC  ...                   NaN
# 18     NBC  ...                   NaN
# 19     NBC  ...                   NaN
# 20     NBC  ...                   NaN
# 21     NBC  ...                   NaN
# 22     NBC  ...                   NaN
# 23    CNBC  ...                   NaN
# 24    CNBC  ...                   NaN
# 25    CNBC  ...                   NaN
# 26    CNBC  ...                   NaN
# 27    CNBC  ...                   NaN
# 28    CNBC  ...                   NaN
# 29    CNBC  ...                   NaN
# 30    CNBC  ...                   NaN
# 31    CNBC  ...                   NaN
# 32    CNBC  ...                   NaN
# 33    CNBC  ...                   NaN
# 34    CNBC  ...                   NaN
# 35    CNBC  ...                   NaN
# 36    CNBC  ...                   NaN
# 37    CNBC  ...                   NaN
# 38    CNBC  ...                   NaN
# 39    CNBC  ...                   NaN
# 40    CNBC  ...                   NaN
# 41    CNBC  ...                   NaN
# 42    CNBC  ...                   NaN
# 43    CNBC  ...                   NaN
# 44    CNBC  ...                   NaN
# 45    CNBC  ...                   NaN
# 46    CNBC  ...                   NaN
# 47    CNBC  ...                   NaN
# 48    CNBC  ...                   NaN
# 49    CNBC  ...                   NaN
# 50    CNBC  ...                   NaN
# 51    CNBC  ...  (Hope Hicks, PERSON)
# 52    CNBC  ...                   NaN
# 53    CNBC  ...                   NaN
#
# [54 rows x 9 columns]
