# %% [markdown]
# <a href="https://colab.research.google.com/github/ritesh-chafer/Coronavirus_Enrichment/blob/master/Web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date
today = date.today()
d = today.strftime("%m-%d-%y")
print("date =", d)
# Out:
# date = 02-21-22

# %%
cnn_url = "https://edition.cnn.com/world/live-news/coronavirus-pandemic-{}-intl/index.html".format(d)

# %%
print(cnn_url)
# Out:
# https://edition.cnn.com/world/live-news/coronavirus-pandemic-02-21-22-intl/index.html

# %%
from bs4 import BeautifulSoup
import requests

# %%
html = requests.get(cnn_url).text

# %%
soup = BeautifulSoup(html)
print(soup.title)
# Out:
# <title>Error</title>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
for link in soup.find_all("h2"):
  print("headline : {}".format(link.text))
  for ent in nlp(link.text).ents:
    print("\text : {}, Entity :{}".format(ent.text,ent.label_))
# Out:
# headline : It could be you, or it could be us, but there's no page here.

# %%
nbc_url = 'https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url = 'https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
urls = [cnn_url, nbc_url, cnbc_rss_url]
formats = ['html.parser','html.parser','xml']
tags = ['h2', 'h2', 'description']
website = ['CNN', 'NBC','CNBC']

# %%
crawl_len=0
for url in urls:
  print("crawling web page ..........{}".format(url))
  response = requests.get(url)
  soup = BeautifulSoup(response.content, formats[crawl_len])
  for link in soup.find_all(tags[crawl_len]):
    if(len(link.text.split(" ")) > 4):
      print("Headline : {}".format(link.text))
      entities = []
      for ent in nlp(link.text).ents:
        print("\tText: {}, Entity:{}".format(ent.text, ent.label_))
  crawl_len = crawl_len+1
# Out:
# crawling web page ..........https://edition.cnn.com/world/live-news/coronavirus-pandemic-02-21-22-intl/index.html
# Headline : It could be you, or it could be us, but there's no page here.
# crawling web page ..........https://www.nbcnews.com/health/coronavirus
# Headline : What you need to know about at-home rapid tests and their results
# Headline : Covid booster shots are rolling out. What does that mean for you?
# Headline : CDC issues urgent alert: Pregnant women need the Covid-19 vaccines
# 	Text: CDC, Entity:ORG
# Headline : Covid hospitalization hot spots across the U.S., in five charts
# 	Text: U.S., Entity:GPE
# 	Text: five, Entity:CARDINAL
# Headline : How to fight the next new Covid variant
# 	Text: Covid, Entity:PRODUCT
# Headline : Taking unvaccinated man off heart transplant list is tragic — but ethical
# Headline : You can't just catch omicron and 'get it over with.' Covid doesn't work that way.
# Headline : THINK: Lessons from the pandemic
# Headline : Don't throw out your Covid masks
# Headline : I moved in with my mom during the pandemic and realized I'd looked at success all wrong
# Headline : Let's keep every outdoor dining option post-Covid. It's time restaurant culture evolved.
# 	Text: post-Covid, Entity:PERSON
# Headline : We are mortal. Accepting that truth helps us live better.
# Headline : What I learned about myself taking short Covid walks — even when I didn't want to
# 	Text: Covid, Entity:PRODUCT
# Headline : Covid and the dawning of a new era of working-class resistance
# Headline : Covid gave me the best birthday party I ever had ― as an adult
# Headline : I've been freed from hugging people. Please don't make me start again
# Headline : Covid Chronicles: An illustrated feature
# Headline : Covid Chronicles, Vol. 1: A nurse's anguish in the ICU
# 	Text: Covid Chronicles, Entity:PERSON
# 	Text: Vol, Entity:GPE
# 	Text: 1, Entity:CARDINAL
# Headline : Covid Chronicles, Vol. 2: 'I think this virus is trying to kill me'
# 	Text: Covid Chronicles, Entity:PERSON
# 	Text: Vol, Entity:GPE
# 	Text: 2, Entity:CARDINAL
# Headline : Covid Chronicles, Vol. 3: Opera singer's voice carries during quarantine
# 	Text: Covid Chronicles, Entity:PERSON
# 	Text: Vol, Entity:GPE
# 	Text: 3, Entity:CARDINAL
# 	Text: Opera singer's, Entity:PERSON
# crawling web page ..........https://www.cnbc.com/id/10000108/device/rss/rss.html
# Headline : Latest news for health care.
# Headline : While EssilorLuxottica has a much larger market capitalization than Warby Parker, the smaller company says it can grow "faster than the overall industry."
# 	Text: EssilorLuxottica, Entity:ORG
# 	Text: Warby Parker, Entity:PERSON
# Headline : Indonesia hit a daily record high of more than 64,000 cases last week, superseding daily infections in the previous wave which peaked just under 57,000 in July.
# 	Text: Indonesia, Entity:GPE
# 	Text: daily, Entity:DATE
# 	Text: more than 64,000, Entity:CARDINAL
# 	Text: last week, Entity:DATE
# 	Text: daily, Entity:DATE
# 	Text: just under 57,000, Entity:CARDINAL
# 	Text: July, Entity:DATE
# Headline : Queen Elizabeth II tested positive for Covid-19 on Sunday and is experiencing mild, cold-like symptoms, Buckingham Palace said.
# 	Text: Queen Elizabeth II, Entity:PERSON
# 	Text: Sunday, Entity:DATE
# 	Text: Buckingham Palace, Entity:FAC
# Headline : Also on the list, what we think is an overdone drop in Abbott and a nice follow through rally for Cisco.
# 	Text: Abbott, Entity:GPE
# 	Text: Cisco, Entity:GPE
# Headline : "We'll have another pandemic. It will be a different pathogen next time," Bill Gates told CNBC.
# 	Text: next time, Entity:DATE
# 	Text: Bill Gates, Entity:PERSON
# 	Text: CNBC, Entity:ORG
# Headline : CNBC's Hadley Gamble discusses what needs to happen to bring an end to the pandemic with Bill Gates and others at the Munich Security Conference.
# 	Text: CNBC, Entity:ORG
# 	Text: Hadley Gamble, Entity:PERSON
# 	Text: Bill Gates, Entity:PERSON
# 	Text: the Munich Security Conference, Entity:FAC
# Headline : However, the Pfizer director and former FDA chief told CNBC on Friday he'll still wear masks in stores as a courtesy. "It's a matter of etiquette."
# 	Text: Pfizer, Entity:ORG
# 	Text: FDA, Entity:ORG
# 	Text: CNBC, Entity:ORG
# 	Text: Friday, Entity:DATE
# Headline : Some with so-called "super immunity" believe now is the safest time to travel during the pandemic. Some medical experts agree; others say it may be too soon.
# Headline : Hong Kong is into its fifth wave, driven by the more transmissible omicron strain.
# 	Text: Hong Kong, Entity:GPE
# 	Text: fifth, Entity:ORDINAL
# Headline : Years ago, UnitedHealth acquired Audax Health, a start-up focused on consumer health tools. Audax no longer exists, but it's part of a bigger idea today.
# 	Text: Years ago, Entity:DATE
# 	Text: UnitedHealth, Entity:ORG
# 	Text: Audax Health, Entity:ORG
# 	Text: today, Entity:DATE
# Headline : California's plan aims to pick up rising viral transmission early and sequence new variants to determine whether vaccines and therapeutics are still effective.
# 	Text: California, Entity:GPE
# Headline : The Defense Department mandated that all service personnel be vaccinated for Covid-19.
# 	Text: The Defense Department, Entity:ORG
# Headline : Dr. Rochelle Walensky said the CDC is focusing more on Covid hospitalizations as the guide to whether public health measures should be lifted.
# 	Text: Rochelle Walensky, Entity:PERSON
# 	Text: CDC, Entity:ORG
# Headline : "It's difficult for managers," on top of short staffing as well as rising costs and supply chain issues, Cameron Mitchell told CNBC on Wednesday.
# 	Text: Cameron Mitchell, Entity:PERSON
# 	Text: CNBC, Entity:ORG
# 	Text: Wednesday, Entity:DATE
# Headline : Some pet owners are turning to cloning so they never have to say goodbye to their furry friends or their social media following.
# Headline : Singapore plans to allow vaccinated visitors from all countries to skip quarantine on arrival when the omicron wave has passed, authorities announced Wednesday.
# 	Text: Singapore, Entity:GPE
# 	Text: Wednesday, Entity:DATE
# Headline : "I think that is a reasonable scenario," Moderna's CEO Stephane Bancel said when asked about the whether the Covid-19 pandemic may now be in its final stages.
# 	Text: Moderna, Entity:GPE
# 	Text: Stephane Bancel, Entity:PERSON
# Headline : The CDC found infants were 61% less likely to be hospitalized with Covid if their mothers received Pfizer or Moderna's vaccine while pregnant.
# 	Text: CDC, Entity:ORG
# 	Text: 61%, Entity:PERCENT
# 	Text: Pfizer, Entity:ORG
# 	Text: Moderna, Entity:GPE
# Headline : The Senate narrowly confirmed Dr. Robert Califf, a prominent cardiologist, as FDA commissioner, over objections to his pharmaceutical industry ties.
# 	Text: Senate, Entity:ORG
# 	Text: Robert Califf, Entity:PERSON
# 	Text: FDA, Entity:ORG
# Headline : The Jumpstart Nova fund has raised $55 million from investors including Eli Lilly, HCA Healthcare and Bank of America to invest in Black health-tech firms.
# 	Text: The Jumpstart Nova, Entity:ORG
# 	Text: $55 million, Entity:MONEY
# 	Text: Eli Lilly, Entity:ORG
# 	Text: HCA Healthcare, Entity:ORG
# 	Text: Bank of America, Entity:ORG
# Headline : Moderna plunged more than 12%, the biggest decline in the S&P 500 as of midafternoon Monday.
# 	Text: Moderna, Entity:ORG
# 	Text: more than 12%, Entity:PERCENT
# 	Text: midafternoon, Entity:TIME
# 	Text: Monday, Entity:DATE
# Headline : "One case in one direction or another can tip the perception of the vaccine's overall effectiveness," said the Pfizer board member and former FDA chief.
# 	Text: One, Entity:CARDINAL
# 	Text: one, Entity:CARDINAL
# 	Text: Pfizer, Entity:ORG
# 	Text: FDA, Entity:ORG
# Headline : Dr. Paul Offit said the expedited plan was based on the assumption the third dose will prove safe and effective, but there's no guarantee that will be the case.
# 	Text: Paul Offit, Entity:PERSON
# 	Text: third, Entity:ORDINAL
# Headline : Pfizer and BioNTech said they needed more data "because rates of infection and illness remain high in children of this age" due to the omicron variant.
# 	Text: Pfizer, Entity:ORG
# Headline : The future course of the pandemic remains uncertain because new variants may emerge as people's immunity to the virus wanes.
# Headline : Some European countries are being urged to "have a little more patience" as Covid restrictions are lifted.
# 	Text: European, Entity:NORP
# 	Text: Covid, Entity:NORP
# Headline : FDA committee members said the trial population of mostly Asian men did not represent the diversity of U.S. patients.
# 	Text: FDA, Entity:ORG
# 	Text: Asian, Entity:NORP
# 	Text: U.S., Entity:GPE
# Headline : "The most important metric for me is hospitalizations. We want to make sure our hospitals aren't overwhelmed," Gov. Ned Lamont told CNBC on Thursday.
# 	Text: Ned Lamont, Entity:PERSON
# 	Text: CNBC, Entity:ORG
# 	Text: Thursday, Entity:DATE
# Headline : Many psychologists and psychiatrists have reported an influx in people seeking mental health support during the pandemic.
# Headline : As Club members know, we're looking to these IPOs as a means of unlocking value by separating the three core operating business.
# 	Text: three, Entity:CARDINAL

# %%
crawl_len = 0
news_dict = []
for url in urls:
  response = requests.get(url)
  soup = BeautifulSoup(response.content, formats[crawl_len])
  for link in soup.find_all(tags[crawl_len]):
    if(len(link.text.split(" ")) > 4):
      entities = []
      entities = [(ent.text, ent.label_) for ent in nlp(link.text).ents]
      news_dict.append({'website':website[crawl_len],'url':url,'headline':link.text,'entities':entities})
  crawl_len = crawl_len + 1

# %%
news_dict
# Out:
# [{'entities': [],
#   'headline': "It could be you, or it could be us, but there's no page here.",
#   'url': 'https://edition.cnn.com/world/live-news/coronavirus-pandemic-02-21-22-intl/index.html',
#   'website': 'CNN'},
#  {'entities': [],
#   'headline': 'What you need to know about at-home rapid tests and their results',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Covid booster shots are rolling out. What does that mean for you?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('CDC', 'ORG')],
#   'headline': 'CDC issues urgent alert: Pregnant women need the Covid-19 vaccines',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.S.', 'GPE'), ('five', 'CARDINAL')],
#   'headline': 'Covid hospitalization hot spots across the U.S., in five charts',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid', 'PRODUCT')],
#   'headline': 'How to fight the next new Covid variant',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Taking unvaccinated man off heart transplant list is tragic — but ethical',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "You can't just catch omicron and 'get it over with.' Covid doesn't work that way.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'THINK: Lessons from the pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Don't throw out your Covid masks",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "I moved in with my mom during the pandemic and realized I'd looked at success all wrong",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('post-Covid', 'PERSON')],
#   'headline': "Let's keep every outdoor dining option post-Covid. It's time restaurant culture evolved.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'We are mortal. Accepting that truth helps us live better.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid', 'PRODUCT')],
#   'headline': "What I learned about myself taking short Covid walks — even when I didn't want to",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Covid and the dawning of a new era of working-class resistance',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Covid gave me the best birthday party I ever had ― as an adult',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "I've been freed from hugging people. Please don't make me start again",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Covid Chronicles: An illustrated feature',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid Chronicles', 'PERSON'),
#    ('Vol', 'GPE'),
#    ('1', 'CARDINAL')],
#   'headline': "Covid Chronicles, Vol. 1: A nurse's anguish in the ICU",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid Chronicles', 'PERSON'),
#    ('Vol', 'GPE'),
#    ('2', 'CARDINAL')],
#   'headline': "Covid Chronicles, Vol. 2: 'I think this virus is trying to kill me'",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Covid Chronicles', 'PERSON'),
#    ('Vol', 'GPE'),
#    ('3', 'CARDINAL'),
#    ("Opera singer's", 'PERSON')],
#   'headline': "Covid Chronicles, Vol. 3: Opera singer's voice carries during quarantine",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Latest news for health care. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('EssilorLuxottica', 'ORG'), ('Warby Parker', 'PERSON')],
#   'headline': 'While EssilorLuxottica has a much larger market capitalization than Warby Parker, the smaller company says it can grow "faster than the overall industry."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Indonesia', 'GPE'),
#    ('daily', 'DATE'),
#    ('more than 64,000', 'CARDINAL'),
#    ('last week', 'DATE'),
#    ('daily', 'DATE'),
#    ('just under 57,000', 'CARDINAL'),
#    ('July', 'DATE')],
#   'headline': 'Indonesia hit a daily record high of more than 64,000 cases last week, superseding daily infections in the previous wave which peaked just under 57,000 in July.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Queen Elizabeth II', 'PERSON'),
#    ('Sunday', 'DATE'),
#    ('Buckingham Palace', 'FAC')],
#   'headline': 'Queen Elizabeth II tested positive for Covid-19 on Sunday and is experiencing mild, cold-like symptoms, Buckingham Palace said.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Abbott', 'GPE'), ('Cisco', 'GPE')],
#   'headline': 'Also on the list, what we think is an overdone drop in Abbott and a nice follow through rally for Cisco.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('next time', 'DATE'),
#    ('Bill Gates', 'PERSON'),
#    ('CNBC', 'ORG')],
#   'headline': '"We\'ll have another pandemic. It will be a different pathogen next time," Bill Gates told CNBC.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('CNBC', 'ORG'),
#    ('Hadley Gamble', 'PERSON'),
#    ('Bill Gates', 'PERSON'),
#    ('the Munich Security Conference', 'FAC')],
#   'headline': "CNBC's Hadley Gamble discusses what needs to happen to bring an end to the pandemic with Bill Gates and others at the Munich Security Conference.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Pfizer', 'ORG'),
#    ('FDA', 'ORG'),
#    ('CNBC', 'ORG'),
#    ('Friday', 'DATE')],
#   'headline': 'However, the Pfizer director and former FDA chief told CNBC on Friday he\'ll still wear masks in stores as a courtesy. "It\'s a matter of etiquette."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': 'Some with so-called "super immunity" believe now is the safest time to travel during the pandemic. Some medical experts agree; others say it may be too soon.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Hong Kong', 'GPE'), ('fifth', 'ORDINAL')],
#   'headline': 'Hong Kong is into its fifth wave, driven by the more transmissible omicron strain.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Years ago', 'DATE'),
#    ('UnitedHealth', 'ORG'),
#    ('Audax Health', 'ORG'),
#    ('today', 'DATE')],
#   'headline': "Years ago, UnitedHealth acquired Audax Health, a start-up focused on consumer health tools. Audax no longer exists, but it's part of a bigger idea today. ",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('California', 'GPE')],
#   'headline': "California's plan aims to pick up rising viral transmission early and sequence new variants to determine whether vaccines and therapeutics are still effective.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The Defense Department', 'ORG')],
#   'headline': 'The Defense Department mandated that all service personnel be vaccinated for Covid-19.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Rochelle Walensky', 'PERSON'), ('CDC', 'ORG')],
#   'headline': 'Dr. Rochelle Walensky said the CDC is focusing more on Covid hospitalizations as the guide to whether public health measures should be lifted.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Cameron Mitchell', 'PERSON'),
#    ('CNBC', 'ORG'),
#    ('Wednesday', 'DATE')],
#   'headline': '"It\'s difficult for managers," on top of short staffing as well as rising costs and supply chain issues, Cameron Mitchell told CNBC on Wednesday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': 'Some pet owners are turning to cloning so they never have to say goodbye to their furry friends or their social media following.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Singapore', 'GPE'), ('Wednesday', 'DATE')],
#   'headline': 'Singapore plans to allow vaccinated visitors from all countries to skip quarantine on arrival when the omicron wave has passed, authorities announced Wednesday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Moderna', 'GPE'), ('Stephane Bancel', 'PERSON')],
#   'headline': '"I think that is a reasonable scenario," Moderna\'s CEO Stephane Bancel said when asked about the whether the Covid-19 pandemic may now be in its final stages.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('CDC', 'ORG'),
#    ('61%', 'PERCENT'),
#    ('Pfizer', 'ORG'),
#    ('Moderna', 'GPE')],
#   'headline': "The CDC found infants were 61% less likely to be hospitalized with Covid if their mothers received Pfizer or Moderna's vaccine while pregnant.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Senate', 'ORG'), ('Robert Califf', 'PERSON'), ('FDA', 'ORG')],
#   'headline': 'The Senate narrowly confirmed Dr. Robert Califf, a prominent cardiologist, as FDA commissioner, over objections to his pharmaceutical industry ties.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The Jumpstart Nova', 'ORG'),
#    ('$55 million', 'MONEY'),
#    ('Eli Lilly', 'ORG'),
#    ('HCA Healthcare', 'ORG'),
#    ('Bank of America', 'ORG')],
#   'headline': 'The Jumpstart Nova fund has raised $55 million from investors including Eli Lilly, HCA Healthcare and Bank of America to invest in Black health-tech firms.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Moderna', 'ORG'),
#    ('more than 12%', 'PERCENT'),
#    ('midafternoon', 'TIME'),
#    ('Monday', 'DATE')],
#   'headline': 'Moderna plunged more than 12%, the biggest decline in the S&P 500 as of midafternoon Monday. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('One', 'CARDINAL'),
#    ('one', 'CARDINAL'),
#    ('Pfizer', 'ORG'),
#    ('FDA', 'ORG')],
#   'headline': '"One case in one direction or another can tip the perception of the vaccine\'s overall effectiveness," said the Pfizer board member and former FDA chief.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Paul Offit', 'PERSON'), ('third', 'ORDINAL')],
#   'headline': "Dr. Paul Offit said the expedited plan was based on the assumption the third dose will prove safe and effective, but there's no guarantee that will be the case.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Pfizer', 'ORG')],
#   'headline': 'Pfizer and BioNTech said they needed more data "because rates of infection and illness remain high in children of this age" due to the omicron variant.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': "The future course of the pandemic remains uncertain because new variants may emerge as people's immunity to the virus wanes.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('European', 'NORP'), ('Covid', 'NORP')],
#   'headline': 'Some European countries are being urged to "have a little more patience" as Covid restrictions are lifted. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('FDA', 'ORG'), ('Asian', 'NORP'), ('U.S.', 'GPE')],
#   'headline': 'FDA committee members said the trial population of mostly Asian men did not represent the diversity of U.S. patients.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Ned Lamont', 'PERSON'),
#    ('CNBC', 'ORG'),
#    ('Thursday', 'DATE')],
#   'headline': '"The most important metric for me is hospitalizations. We want to make sure our hospitals aren\'t overwhelmed," Gov. Ned Lamont told CNBC on Thursday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': 'Many psychologists and psychiatrists have reported an influx in people seeking mental health support during the pandemic.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('three', 'CARDINAL')],
#   'headline': "As Club members know, we're looking to these IPOs as a means of unlocking value by separating the three core operating business.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'}]

# %%
import pandas as pd

# %%
news_df = pd.DataFrame(news_dict)

# %%
pd.set_option('max_colwidth', 800)
news_df.head(30)
# Out:
#    website  ...                                                                                                                                        entities
# 0      CNN  ...                                                                                                                                              []
# 1      NBC  ...                                                                                                                                              []
# 2      NBC  ...                                                                                                                                              []
# 3      NBC  ...                                                                                                                                    [(CDC, ORG)]
# 4      NBC  ...                                                                                                                 [(U.S., GPE), (five, CARDINAL)]
# 5      NBC  ...                                                                                                                              [(Covid, PRODUCT)]
# 6      NBC  ...                                                                                                                                              []
# 7      NBC  ...                                                                                                                                              []
# 8      NBC  ...                                                                                                                                              []
# 9      NBC  ...                                                                                                                                              []
# 10     NBC  ...                                                                                                                                              []
# 11     NBC  ...                                                                                                                          [(post-Covid, PERSON)]
# 12     NBC  ...                                                                                                                                              []
# 13     NBC  ...                                                                                                                              [(Covid, PRODUCT)]
# 14     NBC  ...                                                                                                                                              []
# 15     NBC  ...                                                                                                                                              []
# 16     NBC  ...                                                                                                                                              []
# 17     NBC  ...                                                                                                                                              []
# 18     NBC  ...                                                                                         [(Covid Chronicles, PERSON), (Vol, GPE), (1, CARDINAL)]
# 19     NBC  ...                                                                                         [(Covid Chronicles, PERSON), (Vol, GPE), (2, CARDINAL)]
# 20     NBC  ...                                                               [(Covid Chronicles, PERSON), (Vol, GPE), (3, CARDINAL), (Opera singer's, PERSON)]
# 21    CNBC  ...                                                                                                                                              []
# 22    CNBC  ...                                                                                               [(EssilorLuxottica, ORG), (Warby Parker, PERSON)]
# 23    CNBC  ...  [(Indonesia, GPE), (daily, DATE), (more than 64,000, CARDINAL), (last week, DATE), (daily, DATE), (just under 57,000, CARDINAL), (July, DATE)]
# 24    CNBC  ...                                                                        [(Queen Elizabeth II, PERSON), (Sunday, DATE), (Buckingham Palace, FAC)]
# 25    CNBC  ...                                                                                                                   [(Abbott, GPE), (Cisco, GPE)]
# 26    CNBC  ...                                                                                          [(next time, DATE), (Bill Gates, PERSON), (CNBC, ORG)]
# 27    CNBC  ...                                             [(CNBC, ORG), (Hadley Gamble, PERSON), (Bill Gates, PERSON), (the Munich Security Conference, FAC)]
# 28    CNBC  ...                                                                                        [(Pfizer, ORG), (FDA, ORG), (CNBC, ORG), (Friday, DATE)]
# 29    CNBC  ...                                                                                                                                              []
#
# [30 rows x 4 columns]

# %%
pd.concat([news_df[['website','url','headline']],news_df['entities'].apply(pd.Series)],axis=1)
# Out:
#    website  ...             6
# 0      CNN  ...           NaN
# 1      NBC  ...           NaN
# 2      NBC  ...           NaN
# 3      NBC  ...           NaN
# 4      NBC  ...           NaN
# 5      NBC  ...           NaN
# 6      NBC  ...           NaN
# 7      NBC  ...           NaN
# 8      NBC  ...           NaN
# 9      NBC  ...           NaN
# 10     NBC  ...           NaN
# 11     NBC  ...           NaN
# 12     NBC  ...           NaN
# 13     NBC  ...           NaN
# 14     NBC  ...           NaN
# 15     NBC  ...           NaN
# 16     NBC  ...           NaN
# 17     NBC  ...           NaN
# 18     NBC  ...           NaN
# 19     NBC  ...           NaN
# 20     NBC  ...           NaN
# 21    CNBC  ...           NaN
# 22    CNBC  ...           NaN
# 23    CNBC  ...  (July, DATE)
# 24    CNBC  ...           NaN
# 25    CNBC  ...           NaN
# 26    CNBC  ...           NaN
# 27    CNBC  ...           NaN
# 28    CNBC  ...           NaN
# 29    CNBC  ...           NaN
# 30    CNBC  ...           NaN
# 31    CNBC  ...           NaN
# 32    CNBC  ...           NaN
# 33    CNBC  ...           NaN
# 34    CNBC  ...           NaN
# 35    CNBC  ...           NaN
# 36    CNBC  ...           NaN
# 37    CNBC  ...           NaN
# 38    CNBC  ...           NaN
# 39    CNBC  ...           NaN
# 40    CNBC  ...           NaN
# 41    CNBC  ...           NaN
# 42    CNBC  ...           NaN
# 43    CNBC  ...           NaN
# 44    CNBC  ...           NaN
# 45    CNBC  ...           NaN
# 46    CNBC  ...           NaN
# 47    CNBC  ...           NaN
# 48    CNBC  ...           NaN
# 49    CNBC  ...           NaN
# 50    CNBC  ...           NaN
# 51    CNBC  ...           NaN
#
# [52 rows x 10 columns]
